# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Utilities" data-toc-modified-id="Utilities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Utilities</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plotting</a></span></li><li><span><a href="#Geometry" data-toc-modified-id="Geometry-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Geometry</a></span></li><li><span><a href="#Time-Handling" data-toc-modified-id="Time-Handling-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Time Handling</a></span></li></ul></li><li><span><a href="#Generation-of-Input-Data" data-toc-modified-id="Generation-of-Input-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Generation of Input Data</a></span><ul class="toc-item"><li><span><a href="#Generate-Parcels" data-toc-modified-id="Generate-Parcels-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Generate Parcels</a></span></li><li><span><a href="#Testing-Parcel-Data-Generation" data-toc-modified-id="Testing-Parcel-Data-Generation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Testing Parcel Data Generation</a></span></li><li><span><a href="#Statistical-Analysis-of-Parcel-Data" data-toc-modified-id="Statistical-Analysis-of-Parcel-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Statistical Analysis of Parcel Data</a></span></li></ul></li><li><span><a href="#Shortest-Path-Finding" data-toc-modified-id="Shortest-Path-Finding-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Shortest Path Finding</a></span><ul class="toc-item"><li><span><a href="#A*-Algorithm" data-toc-modified-id="A*-Algorithm-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>A* Algorithm</a></span></li><li><span><a href="#Floyd-Warshall-Algorithm" data-toc-modified-id="Floyd-Warshall-Algorithm-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Floyd-Warshall Algorithm</a></span></li><li><span><a href="#Testing-Shortest-Path" data-toc-modified-id="Testing-Shortest-Path-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Testing Shortest Path</a></span></li></ul></li><li><span><a href="#Create-Roundtrip" data-toc-modified-id="Create-Roundtrip-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Create Roundtrip</a></span><ul class="toc-item"><li><span><a href="#Using-Iterative-Integer-Programming" data-toc-modified-id="Using-Iterative-Integer-Programming-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Using Iterative Integer Programming</a></span></li><li><span><a href="#Using-Heuristic-Method" data-toc-modified-id="Using-Heuristic-Method-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Using Heuristic Method</a></span></li><li><span><a href="#Testing-Generating-Roundtrip" data-toc-modified-id="Testing-Generating-Roundtrip-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Testing Generating Roundtrip</a></span></li></ul></li><li><span><a href="#Recorder" data-toc-modified-id="Recorder-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Recorder</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model</a></span><ul class="toc-item"><li><span><a href="#Class-Parcel" data-toc-modified-id="Class-Parcel-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Class Parcel</a></span></li><li><span><a href="#Class-Customer" data-toc-modified-id="Class-Customer-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Class Customer</a></span></li><li><span><a href="#Class-Driver" data-toc-modified-id="Class-Driver-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Class Driver</a></span></li><li><span><a href="#Class-Delivery-Centre" data-toc-modified-id="Class-Delivery-Centre-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Class Delivery Centre</a></span></li></ul></li><li><span><a href="#Simulation" data-toc-modified-id="Simulation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Simulation</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Simulation-Routine" data-toc-modified-id="Simulation-Routine-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Simulation Routine</a></span></li><li><span><a href="#Model-Verification" data-toc-modified-id="Model-Verification-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Model Verification</a></span></li><li><span><a href="#Run-Small-Simulation" data-toc-modified-id="Run-Small-Simulation-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Run Small Simulation</a></span><ul class="toc-item"><li><span><a href="#Analysing-Working-Time" data-toc-modified-id="Analysing-Working-Time-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Analysing Working Time</a></span></li><li><span><a href="#Analyse-Tour-Length" data-toc-modified-id="Analyse-Tour-Length-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Analyse Tour Length</a></span></li><li><span><a href="#Analyse-Number-of-Left-Over-Parcels" data-toc-modified-id="Analyse-Number-of-Left-Over-Parcels-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Analyse Number of Left-Over Parcels</a></span></li><li><span><a href="#Analyse-Delayed-Parcel-Delivery" data-toc-modified-id="Analyse-Delayed-Parcel-Delivery-7.4.4"><span class="toc-item-num">7.4.4&nbsp;&nbsp;</span>Analyse Delayed Parcel Delivery</a></span></li></ul></li><li><span><a href="#Run-Multiple-Larger-Simulation" data-toc-modified-id="Run-Multiple-Larger-Simulation-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Run Multiple Larger Simulation</a></span><ul class="toc-item"><li><span><a href="#Run-Simulations" data-toc-modified-id="Run-Simulations-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Run Simulations</a></span></li><li><span><a href="#Combine-Simulation" data-toc-modified-id="Combine-Simulation-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>Combine Simulation</a></span></li><li><span><a href="#Analysis" data-toc-modified-id="Analysis-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>Analysis</a></span></li><li><span><a href="#Tour-Length" data-toc-modified-id="Tour-Length-7.5.4"><span class="toc-item-num">7.5.4&nbsp;&nbsp;</span>Tour Length</a></span></li><li><span><a href="#Number-of-Left-Over-Parcels" data-toc-modified-id="Number-of-Left-Over-Parcels-7.5.5"><span class="toc-item-num">7.5.5&nbsp;&nbsp;</span>Number of Left-Over Parcels</a></span></li><li><span><a href="#Delayed-Parcel-Delivery" data-toc-modified-id="Delayed-Parcel-Delivery-7.5.6"><span class="toc-item-num">7.5.6&nbsp;&nbsp;</span>Delayed Parcel Delivery</a></span></li></ul></li></ul></li></ul></div>

# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Plotting

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=5,
            styleP='b-o', lwP=3, msP=1,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, size=6):
    fig = plt.gcf()
    fig.set_size_inches(size, size)
    resolution = 10000
    plt.xlim(0,resolution)
    plt.ylim(0,resolution)
    if not grid:
        plt.axis('off')
    V, E = G
    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if grid:
        plt.grid()
        if text is not None:
            plt.title(text)
    else:
        if text is not None:
            plt.text(0.8*resolution, 0, text)

    plt.show()

# %%
import scipy.stats as stats

def histplot(data, title="", xlabel="",
             width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()
        
    bins=min(50, min(len(data),maxx-minx)//5+1)
    hist=plt.hist(data, density=True, bins=bins)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)
        
    x = np.linspace(minx, maxx, 100)
    y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
    ax.plot(x, y, lw=1, color='red')
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    ax.grid(True)
    plt.show()

# %%
def dailyPlot(data,
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-1, days)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)
    
    ms = 2 if len(data)>100 else 5
    lw = 0.5 if len(data)>100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
def barPlot(count, title=''):
    fig = plt.figure()
    fig.set_figwidth(3 if len(count)<=10 else 5)
    fig.set_figheight(2)
    ax = fig.gca()
    xpos = np.arange(0, len(count))
    labels = [ c for c in range(0, len(count)) ]
    ax.set_xticks(xpos, labels)
    plt.title(title)
    plt.bar(range(0, len(count)), count)

# %% [markdown]
# ## Geometry

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.ceil(math.sqrt((x1-x2)**2+(y1-y2)**2)))

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %%
def day(now):
    return int(now//(24*3600))

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`. It will be used for trace messages.

# %%
def timestamp(t):
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t - secs)*10))
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %% [markdown]
# `nextHour` generates the simulation time for the next time the hour is equal to the requested hour.

# %%
def nextHour(env, hour):
    beginningOfDay = day(env.now)*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# # Generation of Input Data

# %% [markdown]
# ## Generate Parcels

# %% [markdown]
# `generateParcels` returns for each day a list of customers that should receive parcels on that day. The data are generated for a given number of customers and days under assumption that the demand is independent and identically distributed with a mean value

# %%
def generateParcels(days=50, customers=100, 
                    p=0.25, plot=False, log=False):

    # daily delivery demand is generated for each customer 
    # independently using an expovariate distribution
    
    parcelsForCustomersPerDay = [ [] for i in range(days) ]
    parcelsPerCustomer = [ 0 for i in range(customers) ]
    parcelsPerDay = [ 0 for i in range(days) ]

    for c in range(customers):
        cp = []
        t = random.expovariate(p/(24*3600)) # arrival time secs
        d = day(t)
        deliveryDays = []
        while d<days:
            if d not in deliveryDays:
                deliveryDays.append(d)
            parcelsForCustomersPerDay[d].append(c)
            parcelsPerDay[d] += 1
            parcelsPerCustomer[c] += 1
            if d not in cp:
                cp.append(d)
            t += random.expovariate(p/(24*3600))
            d = day(t)
        
        if log:
            print(f"customer {c:3d} "
                  f"expects {parcelsPerCustomer[c]:2d} deliveries "
                  f"on days {str(cp):s}")
    
    if plot:
        
        histplot(parcelsPerCustomer,
                 xlabel=f'Number of Parcels (over {days:3,d} days, p={p:2.2f})',
                 title=f'Number of Parcels per Customer (N={customers:3,d})')
        
        histplot(parcelsPerDay,
                 xlabel=f'Number of Parcels (over {customers:3,d} customers, p={p:2.2f})',
                 title=f'Number of Parcels per Day (N={days:3,d})')
        
    return parcelsForCustomersPerDay

# %% [markdown]
# ## Testing Parcel Data Generation

# %%
random.seed(0)
generateParcels(days=4, customers=5, p=0.5, log=True)
# Out:
# customer   0 expects  1 deliveries on days [3]
# customer   1 expects  3 deliveries on days [1, 3]
# customer   2 expects  2 deliveries on days [3]
# customer   3 expects  1 deliveries on days [1]
# customer   4 expects  2 deliveries on days [1, 2]
# [[], [1, 1, 3, 4], [4], [0, 1, 2, 2]]

# %% [markdown]
# ## Statistical Analysis of Parcel Data

# %%
random.seed(0)
_ = generateParcels(days=1000, customers=1000, p=0.2, plot=True)

# %% [markdown]
# # Shortest Path Finding

# %% [markdown]
# ## A* Algorithm

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# ## Floyd-Warshall Algorithm

# %% [markdown]
# The following is a modified
# [Floyd-Warshall Algorithm](https://en.wikipedia.org/wiki/Floyd–Warshall_algorithm)
# calculating in parallel the distances and the shortest path between vertices in a graph M.

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %% [markdown]
# ## Testing Shortest Path

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
V, E = M
d, p = FW(M)
random.seed(0)
[A, B] = random.sample(V, k=2)
a = V.index(A)
b = V.index(B)
P1 = p[a][b]
L1 = d[a][b]
plotMap(M, T=[A, B], P=P1, text=f"FW path: {L1:d}m")
P2 = shortestPath(M, A, B)
L2 = pathLength(P2)
plotMap(M, T=[A, B], P=P2, text=f"A* path: {L2:d}m")
P1==P2
# Out:
# True

# %% [markdown]
# # Create Roundtrip

# %% [markdown]
# ## Using Iterative Integer Programming

# %%
import pulp

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
def createLoop(M, D, P, T):
    V, E = M
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[V.index(T[i])][V.index(T[j])]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0)
    # print(f"{constraints:d} Constraints")
    prob.solve(solver)
    trips = roundtrips(x, n)
    while len(trips)>1:
        for t in trips:
            prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                            for i in range(0,len(t)-1) ]) <= len(t)-2
            constraints += 1
        # print(f"{constraints:d} Constraints")
        prob.solve(solver)
        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[V.index(T[trip[k]])][V.index(T[trip[k+1]])]
        loop += sub if len(loop)==0 else sub[1:]
    return loop

# %% [markdown]
# ## Using Heuristic Method

# %%
def createLoopH(M, D, P, T, plot=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
    
    V, E = M
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            if plot:
                loop = makeLoop(L)
                plotMap(M, T=L, P=loop, w=W, 
                        grid=True, text=f"{pathLength(loop):,d}m")
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
    return makeLoop(L)

# %% [markdown]
# ## Testing Generating Roundtrip

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
D, P = FW(M)

# %%
random.seed(0)
customers = random.sample(C, k=6)

# %%
L = createLoop(M, D, P, [W]+customers)

# %%
plotMap(M, T=customers, P=L, w=W, 
        text=f"IP Solution: {pathLength(L):,d}m")

# %%
L2 = createLoopH(M, D, P, [W]+customers)

# %%
plotMap(M, T=customers, P=L, w=W, 
        text=f"Heuristic SolutionL {pathLength(L):,d}m")

# %% [markdown]
# # Recorder

# %%
def combineRecorders(recs): 
    M = recs[0].M
    W = recs[0].W
    C = recs[0].C
    days = sum( [ rec.days for rec in recs ] )
    parcels = sum( [ rec.parcels for rec in recs ])
    # ensure the models are compatible
    for rec in recs[1:]:
        assert(M == rec.M)
        assert(W == rec.W)
        assert(C == rec.C)
        
    r = Recorder(None, M, W, C, days, parcels)
    
    # join the data frames
    r.daily = pd.concat([ rec.daily for rec in recs ], ignore_index=True)
    r.precs = pd.concat([ rec.precs for rec in recs ], ignore_index=True)
    return r

# %%
class Recorder:
    
    def __init__(self, env, M, W, C, days, parcels,
                 log=False, plot=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.parcels = parcels
        self.log = log
        self.plot = plot
        Customer.REGISTER = []
        Parcel.REGISTER = []
                
        # create a data frame for time records per working day
        self.daily = pd.DataFrame()
        self.daily['begin'] = [None]*days
        self.daily['end'] = [None]*days
        self.daily['dist'] = [None]*days
        self.daily['left'] = [None]*days
        
        # create a data frame for records per parcel
        self.precs = pd.DataFrame()
        self.precs['arrived'] = [None]*parcels
        self.precs['delivered'] = [None]*parcels

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end'] = int(round(self.env.now))

    def recordTourLength(self, length):
        self.daily.at[day(self.env.now), 'dist'] = int(length)

    def recordParcelsLeftOver(self, numberOfParcels):
        self.trace(f"{numberOfParcels:d} left over for next day")
        self.daily.at[day(self.env.now), 'left'] = numberOfParcels

    def recordParcelArrival(self, parcel):
        self.trace(f"{str(parcel):s} arrived in delivery centre")
        self.precs.at[parcel.i, 'arrived'] = day(self.env.now)
        
    def recordParcelDelivery(self, parcel):
        self.trace(f"{str(parcel):s} delivered to customer")
        self.precs.at[parcel.i, 'delivered'] = day(self.env.now)

    def finish(self):
        self.daily['time'] = self.daily['end']-self.daily['begin']
        # if at the end of the simulation there are parcels 
        # not yet delivered, register them for the next day
        for i in range(self.parcels):
            if self.precs.at[i, 'delivered'] is None:
                self.precs.at[i, 'delivered'] = self.days
        self.precs['delay'] = self.precs['delivered']-self.precs['arrived']
        # calculate max delay time of parcels delivered on a day
        self.daily['maxdelay'] = [0] * self.days
        for i in range(self.parcels):
            deliveryDay = self.precs.at[i, 'delivered']
            if deliveryDay < self.days:
                if self.daily.at[deliveryDay, 'maxdelay'] < self.precs.at[i, 'delay']:
                    self.daily.at[deliveryDay, 'maxdelay'] = self.precs.at[i, 'delay']
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None
        
    def histWorkingTime(self):
        histplot(self.daily['time']//60,
                 xlabel='Working Time [min]',
                 title='Daily Working Time')
        
    def plotWorkingTime(self):
        dailyPlot(self.daily['time']//60,
                  ylabel='Working Time [min]',
                  title='Daily Working Time')
            
    def histTourLength(self):
        histplot(self.daily['dist'],
                 xlabel='Tour Length [m]',
                 title='Daily Tour Length')
            
    def plotTourLength(self):
        dailyPlot(self.daily['dist'],
                  ylabel='Tour Length [m]',
                  title='Daily Tour Length')
            
    def histLeftOver(self):
        histplot(self.daily['left'],
                 xlabel='Left-Over Parcels',
                 title='Daily Left-Over Parcels')
                
    def plotLeftOver(self):
        dailyPlot(self.daily['left'],
                  ylabel='Number of Parcels',
                  title='Daily Left-Over Parcels')
        
    def plotParcelDelay(self):
        dailyPlot(self.daily['maxdelay'],
                  ylabel='Max Delay [days]',
                  title='Max Delivery Delay')
        
    def barplotParcelDelay(self):
        maxDelay = max(self.precs['delay'])
        count = [ 0 for c in range(maxDelay+1) ]
        for i in range(self.parcels):
            count[self.precs.at[i, 'delay']] += 1
        barPlot(count, title='Parcel Delay [days]')
        
    def tableParcelDelay(self):
        maxDelay = max(self.precs['delay'])
        count = [ 0 for c in range(maxDelay+1) ]
        for i in range(self.parcels):
            count[self.precs.at[i, 'delay']] += 1
        print(f'Delivery Delay ({self.parcels:d} parcels)')
        print(f'{"None":>7s}:   {count[0]:4d}   {count[0]/self.parcels*100:4.1f}%')
        for c in range(1, len(count)):
            print(f'{c:2d} days:   {count[c]:4d}   {count[c]/self.parcels*100:4.1f}%')

# %% [markdown]
# # Model

# %% [markdown]
# ## Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    REGISTER = []
    
    def __init__(self, rec, cust):
        self.rec = rec
        self.cust = cust
        self.dest = cust.location
        self.status = [ ] # status record and
        self.timing = [ ] # timing
        self.i = len(Parcel.REGISTER)
        Parcel.REGISTER.append(self)

    def __str__(self):
        return f"Parcel: {self.i:2d} for customer {self.cust.i:d}"
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')
        
    def delivered(self):
        self.rec.recordParcelDelivery(parcel)
        self.__reg('delivered to customer')

# %% [markdown]
# ## Class Customer

# %% [markdown]
# The customer is considered passive. The customer is at home with q given probability `q`. The time to answer the door is
# given with an expovariate distribution. When the customer is not answering within a certain period of time, the parcel is returned to the delivery centre.

# %%
class Customer:
    
    REGISTER = []

    def __init__(self, rec, location, q):
        self.rec = rec
        self.location = location
        self.q = q
        self.parcelsReceived = []
        self.i = len(Customer.REGISTER)
        Customer.REGISTER.append(self)
        
        
    def __str__(self):
        return f"Customer: {self.i:2d} {str(self.location):s}"
    
    # factory method ensures that there is only
    # one customer per location
    def getCustomer(rec, location, q=None):
        for c in Customer.REGISTER:
            if c.location == location:
                return c
        assert(q is not None)
        return Customer(rec, location, q)
    
    def responseTime(self):
        if random.random()<self.q:
            return math.inf # customer is not home
        else:
            return random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            
    def acceptParcel(self, parcel):
        self.parcelsReceived.append(parcel.i)
        self.rec.recordParcelDelivery(parcel)

# %% [markdown]
# ## Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver v5.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC, patience):
        self.rec = rec
        self.DC = DC
        self.patience = patience
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.recordDriverBeginsWork()
        
    def leaveForDelivery(self, tour, parcels):
        for p in parcels:
            yield self.rec.env.timeout(PREP_TIME_PER_PARCEL)
            p.outForDelivery()
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " \
                       f"of {len(parcels):d} parcels")
                
    def goHome(self):
        self.location = self.DC.W
        self.parcels = None
        self.returns = None
        self.tour = [ self.DC.W ]
        self.rec.recordDriverEndsWork()
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels = self.DC.sendForDelivery()
            yield from self.leaveForDelivery(tour, parcels)
            self.rec.recordTourLength(pathLength(tour))
            while len(self.parcels)>0:
                # drive to customer
                custLocation = self.parcels[0].dest
                cust = Customer.getCustomer(self.rec, custLocation)
                self.rec.trace("Driver drives to "+str(cust))
                yield from self.__drive(custLocation)
                self.rec.trace("Driver arrived at "+str(cust))
                wait_time = cust.responseTime()
                
                if wait_time<self.patience: 
                    # customer answered door

                    yield self.rec.env.timeout(wait_time)
                    self.rec.trace(str(cust)+" answers door")
                    while len(self.parcels)>0 and \
                            custLocation == self.parcels[0].dest:
                        handover_time = random.expovariate(1/AVERAGE_TIME_HANDOVER)
                        yield self.rec.env.timeout(handover_time)
                        cust.acceptParcel(self.parcels[0])
                        self.parcels = self.parcels[1:]
                    signoff_time = random.expovariate(1/AVERAGE_TIME_SIGNOFF)
                    yield self.rec.env.timeout(signoff_time)
                    self.rec.trace(str(cust)+" signed off")
                else:
                    # customer not at home or to slow
                    yield self.rec.env.timeout(self.patience)
                    self.rec.trace(str(cust)+" doesn't answer the door")
                    while len(self.parcels)>0 and  \
                            custLocation == self.parcels[0].dest:
                        self.returns.append(self.parcels[0])
                        self.parcels = self.parcels[1:]

            # return to delivery centre
            self.rec.trace("Driver returns to delivery centre")
            yield from self.__drive(self.DC.W)
            yield from self.DC.returnFromDelivery(self.returns)
            
            self.rec.recordParcelsLeftOver(len(self.DC.parcels)+
                                           len(self.DC.leftOver))

            self.goHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# ## Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W, limit, heuristic):
        self.rec = rec
        self.M = M
        self.W = W
        self.D, self.P = FW(M)
        self.limit = limit
        self.heuristic = heuristic
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [W]       # tour planned for delivery
        
    # builds tour incrementally:
    # every single parcel is in the sequence of their
    # acceptance either incorporated into the tour or
    # assigned to left overs 
    def __accept(self, parcel):
        custLoc = parcel.dest
        if custLoc in self.dest:
            self.parcels.append(parcel)
        else:
            if self.heuristic:
                S = createLoopH(self.M, self.D, self.P, [self.W] + self.dest + [custLoc])
            else:
                S = createLoop(self.M, self.D, self.P, [self.W] + self.dest + [custLoc])
            if pathLength(S)<self.limit:
                self.parcels.append(parcel)
                self.dest.append(custLoc)
                self.tour = S
            else:
                self.leftOver.append(parcel)
            
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.rec.recordParcelArrival(parcel)
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = self.dest
        
        # pick parcels in sequence to be delivered
        for dest in tour:
            if dest in self.dest:
                for p in self.parcels:
                    if p.dest == dest:
                        parcels += [p]
         
        # rearrange the left overs
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)
        
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    grid=True, size=5,
                    text=f"Day {day(self.rec.env.now):2d}, {pathLength(tour):,d}m")

        return tour, parcels
                 
    def returnFromDelivery(self, parcels):
        for p in parcels:
            p.returnFromDelivery()
            yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
            self.__accept(p)
        yield self.rec.env.timeout(END_OF_DAY_TIME)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# The time to **process returned parcels** in the delivery centre is 30 sec per parcel.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average **customer time** to answer the door, accept a parcel, or signoff.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40
AVERAGE_TIME_HANDOVER = 10
AVERAGE_TIME_SIGNOFF = 10

# %% [markdown]
# The time for end of day closing procedure

# %%
END_OF_DAY_TIME = 600

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C,      # map geometry
               days,         # run simulation for number of days
               p=0.2,        # parcels per day and customer, 
               limit=30000,  # bike range limit
               q=0.1,        # probability that the customer is not at home 
               patience=60,  # max wait time for customer answering door
               heuristic=False, log=False, plot=False, ticks=False):

    P = generateParcels(days=days, p=p, customers=len(C))
        
    parcels = sum([ len(d) for d in P ])
    
    print(f"Simulating the delivery of {parcels:d} parcels "
          f"over {days:d} days to {len(C):d} customers") 
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, parcels, log=log, plot=plot)

    def generatorProcess(env):
                
        DC = DeliveryCentre(rec, M, W, limit, heuristic)
        D = Driver(rec, DC, patience)
        
        # process the parcels day by day
        for CL in P: 
            
            if log:
                print()
            if ticks:
                print(".", end="")

            yield env.timeout(12*3600) # days
            for ci in CL:
                cust = Customer.getCustomer(rec, C[ci], q)
                p = Parcel(rec, cust)
                DC.acceptParcel(p)
            yield env.timeout(12*3600) # days

    env.process(generatorProcess(env))
    env.run()
    
    rec.finish()
    
    return rec

# %% [markdown]
# ## Model Verification

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
C
# Out:
# [(7877, 4169),
#  (6341, 4279),
#  (3326, 7751),
#  (3913, 6505),
#  (6924, 2845),
#  (3677, 5433),
#  (6821, 5891),
#  (7296, 4962),
#  (7397, 3141),
#  (3747, 3059)]

# %%
W
# Out:
# (8001, 7207)

# %%
M
# Out:
# ([(2523, 5360),
#   (2596, 7555),
#   (3349, 3238),
#   (4150, 5463),
#   (4582, 7057),
#   (4761, 3761),
#   (5122, 2445),
#   (5233, 8264),
#   (6171, 6537),
#   (6177, 3254),
#   (6458, 5010),
#   (6832, 9464),
#   (7787, 4934),
#   (8001, 7207),
#   (8005, 3086),
#   (7877, 4169),
#   (6341, 4279),
#   (3326, 7751),
#   (3913, 6505),
#   (6924, 2845),
#   (3677, 5433),
#   (6821, 5891),
#   (7296, 4962),
#   (7397, 3141),
#   (3747, 3059)],
#  [((2523, 5360), (4761, 3761)),
#   ((2523, 5360), (2596, 7555)),
#   ((3349, 3238), (2523, 5360)),
#   ((4582, 7057), (5233, 8264)),
#   ((4761, 3761), (3349, 3238)),
#   ((4761, 3761), (4150, 5463)),
#   ((4761, 3761), (6458, 5010)),
#   ((5122, 2445), (6177, 3254)),
#   ((5233, 8264), (6832, 9464)),
#   ((6832, 9464), (6171, 6537)),
#   ((7787, 4934), (8001, 7207)),
#   ((8001, 7207), (6171, 6537)),
#   ((8001, 7207), (6832, 9464)),
#   ((8005, 3086), (7877, 4169)),
#   ((7877, 4169), (7787, 4934)),
#   ((6177, 3254), (6341, 4279)),
#   ((6341, 4279), (6458, 5010)),
#   ((5233, 8264), (3326, 7751)),
#   ((3326, 7751), (2596, 7555)),
#   ((4582, 7057), (3913, 6505)),
#   ((3913, 6505), (2523, 5360)),
#   ((8005, 3086), (6924, 2845)),
#   ((6924, 2845), (5122, 2445)),
#   ((4150, 5463), (3677, 5433)),
#   ((3677, 5433), (2523, 5360)),
#   ((6171, 6537), (6821, 5891)),
#   ((6821, 5891), (7787, 4934)),
#   ((6458, 5010), (7296, 4962)),
#   ((7296, 4962), (7787, 4934)),
#   ((6177, 3254), (7397, 3141)),
#   ((7397, 3141), (8005, 3086)),
#   ((3349, 3238), (3747, 3059)),
#   ((3747, 3059), (5122, 2445))])

# %%
plotMap(M, T=C, w=W, text='Sample Data', grid=True)

# %%
random.seed(0)
_ = simulation(M, W, C, days=4, p=0.2, limit=30000, log=True, plot=True)
# Out:
# Simulating the delivery of 4 parcels over 4 days to 10 customers
#
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Driver leaves for delivery of 0 parcels
# [ 0] 18:00:00.0 Driver returns to delivery centre
# [ 0] 18:10:00.0 0 left over for next day
# [ 0] 18:10:00.0 Driver goes home
#
# [ 1] 12:00:00.0 Parcel:  0 for customer 0 arr at delivery centre
# [ 1] 12:00:00.0 Parcel:  0 for customer 0 arrived in delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:50.0 Parcel:  0 for customer 0 out for delivery
# [ 1] 18:00:50.0 Driver leaves for delivery of 1 parcels
# [ 1] 18:00:50.0 Driver drives to Customer:  0 (3677, 5433)
# [ 1] 18:32:51.7 Driver arrived at Customer:  0 (3677, 5433)
# [ 1] 18:33:03.2 Customer:  0 (3677, 5433) answers door
# [ 1] 18:33:27.3 Parcel:  0 for customer 0 delivered to customer
# [ 1] 18:34:07.9 Customer:  0 (3677, 5433) signed off
# [ 1] 18:34:07.9 Driver returns to delivery centre
# [ 1] 19:16:09.6 0 left over for next day
# [ 1] 19:16:09.6 Driver goes home
#
# [ 2] 12:00:00.0 Parcel:  1 for customer 1 arr at delivery centre
# [ 2] 12:00:00.0 Parcel:  1 for customer 1 arrived in delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:50.0 Parcel:  1 for customer 1 out for delivery
# [ 2] 18:00:50.0 Driver leaves for delivery of 1 parcels
# [ 2] 18:00:50.0 Driver drives to Customer:  1 (3326, 7751)
# [ 2] 18:26:54.1 Driver arrived at Customer:  1 (3326, 7751)
# [ 2] 18:27:54.1 Customer:  1 (3326, 7751) doesn't answer the door
# [ 2] 18:27:54.1 Driver returns to delivery centre
# [ 2] 18:53:58.2 Parcel:  1 for customer 1 return from delivery
# [ 2] 19:04:28.2 1 left over for next day
# [ 2] 19:04:28.2 Driver goes home
#
# [ 3] 12:00:00.0 Parcel:  2 for customer 2 arr at delivery centre
# [ 3] 12:00:00.0 Parcel:  2 for customer 2 arrived in delivery centre
# [ 3] 12:00:00.0 Parcel:  3 for customer 3 arr at delivery centre
# [ 3] 12:00:00.0 Parcel:  3 for customer 3 arrived in delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:50.0 Parcel:  1 for customer 1 out for delivery
# [ 3] 18:01:40.0 Parcel:  2 for customer 2 out for delivery
# [ 3] 18:02:30.0 Parcel:  3 for customer 3 out for delivery
# [ 3] 18:02:30.0 Driver leaves for delivery of 3 parcels
# [ 3] 18:02:30.0 Driver drives to Customer:  1 (3326, 7751)
# [ 3] 18:28:34.1 Driver arrived at Customer:  1 (3326, 7751)
# [ 3] 18:29:26.4 Customer:  1 (3326, 7751) answers door
# [ 3] 18:29:49.3 Parcel:  1 for customer 1 delivered to customer
# [ 3] 18:30:00.9 Customer:  1 (3326, 7751) signed off
# [ 3] 18:30:00.9 Driver drives to Customer:  2 (3913, 6505)
# [ 3] 18:46:52.5 Driver arrived at Customer:  2 (3913, 6505)
# [ 3] 18:46:56.7 Customer:  2 (3913, 6505) answers door
# [ 3] 18:47:02.4 Parcel:  2 for customer 2 delivered to customer
# [ 3] 18:47:11.8 Customer:  2 (3913, 6505) signed off
# [ 3] 18:47:11.8 Driver drives to Customer:  3 (7397, 3141)
# [ 3] 19:21:30.6 Driver arrived at Customer:  3 (7397, 3141)
# [ 3] 19:22:30.6 Customer:  3 (7397, 3141) doesn't answer the door
# [ 3] 19:22:30.6 Driver returns to delivery centre
# [ 3] 19:41:32.2 Parcel:  3 for customer 3 return from delivery
# [ 3] 19:52:02.2 1 left over for next day
# [ 3] 19:52:02.2 Driver goes home

# %% [markdown]
# ## Run Small Simulation

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
random.seed(0)
rec = simulation(M, W, C, days=10, p=0.2, limit=30000, 
                 heuristic=True, plot=True)
# Out:
# Simulating the delivery of 17 parcels over 10 days to 10 customers

# %% [markdown]
# ### Analysing Working Time

# %%
rec.histWorkingTime()

# %%
rec.plotWorkingTime()

# %% [markdown]
# ### Analyse Tour Length

# %%
rec.histTourLength()

# %%
rec.plotTourLength()

# %% [markdown]
# ### Analyse Number of Left-Over Parcels

# %%
rec.histLeftOver()

# %%
rec.plotLeftOver()

# %% [markdown]
# ### Analyse Delayed Parcel Delivery

# %%
rec.tableParcelDelay()
# Out:
# Delivery Delay (17 parcels)
#    None:      9   52.9%
#  1 days:      6   35.3%
#  2 days:      2   11.8%

# %%
rec.barplotParcelDelay()

# %%
rec.plotParcelDelay()

# %% [markdown]
# ## Run Multiple Larger Simulation

# %%
def multiSimulation(seeds,        # seed values for simulation runs   
                    M, W, C,      # Geometry data
                    days=50,      # run simulation for number of days
                    p=0.2,        # parcels per day and customer, 
                    limit=30000,  # bike range limit
                    q=0.1,        # probability that the customer is not at home 
                    patience=60): # max wait time for customer answering door
    for seed in seeds:
        random.seed(seed)
        filename = f"rec days={days:d} p={p:2.2f} limit={limit:d} " + \
                   f"q={q:2.2f} patience={patience:d} seed={seed:d}"
        print(filename)
        rec = simulation(M, W, C, 
                         days=days, p=p, limit=limit, q=q, patience=patience, 
                         heuristic=True, ticks=True)
        with open('C:\\Users\\Adesoji\\Documents\\Me - Masters\\Semester 2\\Modelling, Simulation and Optimization\\Material for CA\\Final\\res\\'+filename, 'wb') as f:
            pickle.dump(rec, f)
        print()

# %%
def loadSimulations(seeds,        # seed values for simulation runs   
                    days=50,      # run simulation for number of days
                    p=0.2,        # parcels per day and customer, 
                    limit=30000,  # bike range limit
                    q=0.1,        # probability that the customer is not at home 
                    patience=60): # max wait time for customer answering door
    recs = []
    for seed in seeds:
        random.seed(seed)
        filename = f"rec days={days:d} p={p:2.2f} limit={limit:d} " + \
                   f"q={q:2.2f} patience={patience:d} seed={seed:d}"
        print(filename)
        with open('C:\\Users\\Adesoji\\Documents\\Me - Masters\\Semester 2\\Modelling, Simulation and Optimization\\Material for CA\\Final\\res\\'+filename, 'rb') as f:
            rec = pickle.load(f)
            recs.append(rec)
    return recs

# %% [markdown]
# ### Run Simulations

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
multiSimulation(range(10), M, W, C, limit=30000, days=50)
# Out:
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=0
# Simulating the delivery of 84 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=1
# Simulating the delivery of 108 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=2
# Simulating the delivery of 85 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=3
# Simulating the delivery of 81 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=4
# Simulating the delivery of 106 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=5
# Simulating the delivery of 91 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=6
# Simulating the delivery of 92 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=7
# Simulating the delivery of 114 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=8
# Simulating the delivery of 106 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=9
# Simulating the delivery of 112 parcels over 50 days to 10 customers
# ..................................................

# %% [markdown]
# ### Combine Simulation

# %%
recs = loadSimulations(range(10), limit=30000, days=50)
# Out:
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=9

# %%
rec = combineRecorders(recs)

# %% [markdown]
# ### Analysis

# %%
rec.histWorkingTime()

# %%
rec.histTourLength()

# %%
rec.histLeftOver()

# %%
rec.tableParcelDelay()
# Out:
# Delivery Delay (979 parcels)
#    None:    658   67.2%
#  1 days:    220   22.5%
#  2 days:     66    6.7%
#  3 days:     23    2.3%
#  4 days:     10    1.0%
#  5 days:      0    0.0%
#  6 days:      1    0.1%
#  7 days:      1    0.1%

# %%
rec.barplotParcelDelay()

# %% [markdown]
# ### Testing Simulation for a 40km bike

# %%
multiSimulation(range(10), M, W, C, limit=40000, days=50)
# Out:
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=0
# Simulating the delivery of 84 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=1
# Simulating the delivery of 108 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=2
# Simulating the delivery of 85 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=3
# Simulating the delivery of 81 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=4
# Simulating the delivery of 106 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=5
# Simulating the delivery of 91 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=6
# Simulating the delivery of 92 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=7
# Simulating the delivery of 114 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=8
# Simulating the delivery of 106 parcels over 50 days to 10 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=9
# Simulating the delivery of 112 parcels over 50 days to 10 customers
# ..................................................

# %%
recs = loadSimulations(range(10), limit=40000, days=50)
# Out:
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=9

# %%
rec = combineRecorders(recs)

# %%
rec.tableParcelDelay()
# Out:
# Delivery Delay (979 parcels)
#    None:    660   67.4%
#  1 days:    219   22.4%
#  2 days:     65    6.6%
#  3 days:     23    2.3%
#  4 days:     10    1.0%
#  5 days:      0    0.0%
#  6 days:      1    0.1%
#  7 days:      1    0.1%

# %% [markdown]
# ### Analysis

# %%
rec.histWorkingTime()

# %%
rec.histTourLength()

# %%
rec.histLeftOver()

# %%
rec.tableParcelDelay()
# Out:
# Delivery Delay (979 parcels)
#    None:    660   67.4%
#  1 days:    219   22.4%
#  2 days:     65    6.6%
#  3 days:     23    2.3%
#  4 days:     10    1.0%
#  5 days:      0    0.0%
#  6 days:      1    0.1%
#  7 days:      1    0.1%

# %%
rec.barplotParcelDelay()

# %% [markdown]
# # Simulation with the Real genereated Data

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %% [markdown]
# We are going to run simulations for 4 p values for 10 seeds. The p values choseen are **0.2, 0.23, 0.27 and 0.3**

# %% [markdown]
# ## Simulation for **30km** Bike with 4 different p values (0.2, 0.23, 0.27 and 0.3)

# %%
multiSimulation(range(10), M, W, C, p = 0.2)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.23)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.27)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.3)
# Out:
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=0
# Simulating the delivery of 985 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=1
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=2
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=3
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=4
# Simulating the delivery of 982 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1020 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1004 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=8
# Simulating the delivery of 976 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1014 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1173 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1120 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1118 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1150 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1094 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1207 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1116 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1192 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1152 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1163 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1346 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1319 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1321 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1379 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1326 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1355 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1338 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1349 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1465 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1492 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1516 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1426 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1573 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1484 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1551 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1507 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................

# %%
recs1 = loadSimulations(range(10), p = 0.2)
print("\n")
recs2 = loadSimulations(range(10), p = 0.23)
print("\n")
recs3 = loadSimulations(range(10), p = 0.27)
print("\n")
recs4 = loadSimulations(range(10), p = 0.3)
# Out:
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=30000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=0
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=1
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=2
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=3
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=4
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=5
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=6
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=7
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=8
# rec days=50 p=0.23 limit=30000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=0
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=1
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=2
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=3
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=4
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=5
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=6
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=7
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=8
# rec days=50 p=0.27 limit=30000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=0
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=1
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=2
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=3
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=4
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=5
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=6
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=7
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=8
# rec days=50 p=0.30 limit=30000 q=0.10 patience=60 seed=9

# %%
rec1 = combineRecorders(recs1)
rec2 = combineRecorders(recs2)
rec3 = combineRecorders(recs3)
rec4 = combineRecorders(recs4)

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Working Time

# %%
rec1.histWorkingTime()
rec2.histWorkingTime()
rec3.histWorkingTime()
rec4.histWorkingTime()
# Fig 1 Histogram plot Daily Working Time for 30 km bike

# %%
rec1.plotWorkingTime()
rec2.plotWorkingTime()
rec3.plotWorkingTime()
rec4.plotWorkingTime()
# Fig.2 Daily working time for 30 km bike

# %% [markdown]
# #### Tour Length

# %%
rec1.histTourLength()
rec2.histTourLength()
rec3.histTourLength()
rec4.histTourLength()
# Tour length 30km

# %% [markdown]
# #### Left Over

# %%
rec1.histLeftOver()
rec2.histLeftOver()
rec3.histLeftOver()
rec4.histLeftOver()
# Left Over 30 km

# %% [markdown]
# #### Parcel Delay

# %%
rec1.tableParcelDelay()
print("\n")
rec2.tableParcelDelay()
print("\n")
rec3.tableParcelDelay()
print("\n")
rec4.tableParcelDelay()

# Parcel Delay 30km
# Out:
# Delivery Delay (9998 parcels)
#    None:   2147   21.5%
#  1 days:   2399   24.0%
#  2 days:   2653   26.5%
#  3 days:   1027   10.3%
#  4 days:    588    5.9%
#  5 days:    502    5.0%
#  6 days:    265    2.7%
#  7 days:    153    1.5%
#  8 days:    112    1.1%
#  9 days:     56    0.6%
# 10 days:     36    0.4%
# 11 days:     19    0.2%
# 12 days:     20    0.2%
# 13 days:      5    0.1%
# 14 days:      8    0.1%
# 15 days:      4    0.0%
# 16 days:      0    0.0%
# 17 days:      1    0.0%
# 18 days:      1    0.0%
# 19 days:      0    0.0%
# 20 days:      1    0.0%
# 21 days:      0    0.0%
# 22 days:      1    0.0%
#
#
# Delivery Delay (11485 parcels)
#    None:   2371   20.6%
#  1 days:   2516   21.9%
#  2 days:   2866   25.0%
#  3 days:   1476   12.9%
#  4 days:    771    6.7%
#  5 days:    607    5.3%
#  6 days:    355    3.1%
#  7 days:    161    1.4%
#  8 days:    127    1.1%
#  9 days:     83    0.7%
# 10 days:     63    0.5%
# 11 days:     26    0.2%
# 12 days:     23    0.2%
# 13 days:     17    0.1%
# 14 days:     10    0.1%
# 15 days:      4    0.0%
# 16 days:      0    0.0%
# 17 days:      3    0.0%
# 18 days:      2    0.0%
# 19 days:      0    0.0%
# 20 days:      1    0.0%
# 21 days:      0    0.0%
# 22 days:      2    0.0%
# 23 days:      0    0.0%
# 24 days:      1    0.0%
#
#
# Delivery Delay (13531 parcels)
#    None:   2765   20.4%
#  1 days:   2788   20.6%
#  2 days:   2901   21.4%
#  3 days:   2116   15.6%
#  4 days:    817    6.0%
#  5 days:    719    5.3%
#  6 days:    548    4.0%
#  7 days:    290    2.1%
#  8 days:    194    1.4%
#  9 days:    140    1.0%
# 10 days:     91    0.7%
# 11 days:     51    0.4%
# 12 days:     38    0.3%
# 13 days:     22    0.2%
# 14 days:     19    0.1%
# 15 days:      8    0.1%
# 16 days:      8    0.1%
# 17 days:      4    0.0%
# 18 days:      2    0.0%
# 19 days:      4    0.0%
# 20 days:      2    0.0%
# 21 days:      0    0.0%
# 22 days:      1    0.0%
# 23 days:      3    0.0%
#
#
# Delivery Delay (15010 parcels)
#    None:   3033   20.2%
#  1 days:   3065   20.4%
#  2 days:   3148   21.0%
#  3 days:   2423   16.1%
#  4 days:    944    6.3%
#  5 days:    813    5.4%
#  6 days:    639    4.3%
#  7 days:    307    2.0%
#  8 days:    212    1.4%
#  9 days:    160    1.1%
# 10 days:     88    0.6%
# 11 days:     66    0.4%
# 12 days:     50    0.3%
# 13 days:     22    0.1%
# 14 days:     16    0.1%
# 15 days:     12    0.1%
# 16 days:      4    0.0%
# 17 days:      4    0.0%
# 18 days:      2    0.0%
# 19 days:      2    0.0%

# %%
rec1.barplotParcelDelay()
rec2.barplotParcelDelay()
rec3.barplotParcelDelay()
rec4.barplotParcelDelay()

# %% [markdown]
# ## Simulation for 35km Bike with 4 different p values (0.2, 0.23, 0.27 and 0.3)

# %%
multiSimulation(range(10), M, W, C, p = 0.2, limit = 35000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.23, limit = 35000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.27, limit = 35000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.3, limit = 35000)
# Out:
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=0
# Simulating the delivery of 985 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=1
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=2
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=3
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=4
# Simulating the delivery of 982 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1020 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1004 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=8
# Simulating the delivery of 976 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1014 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1173 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1120 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1118 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1150 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1094 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1207 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1116 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1192 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1152 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1163 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1346 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1319 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1321 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1379 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1326 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1355 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1338 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1349 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1465 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1492 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1516 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1426 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1573 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1484 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1551 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1507 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................

# %%
recs5 = loadSimulations(range(10), p = 0.2, limit = 35000)
print("\n")
recs6 = loadSimulations(range(10), p = 0.23, limit = 35000)
print("\n")
recs7 = loadSimulations(range(10), p = 0.27, limit = 35000)
print("\n")
recs8 = loadSimulations(range(10), p = 0.3, limit = 35000)
# Out:
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=35000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=0
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=1
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=2
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=3
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=4
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=5
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=6
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=7
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=8
# rec days=50 p=0.23 limit=35000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=0
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=1
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=2
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=3
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=4
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=5
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=6
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=7
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=8
# rec days=50 p=0.27 limit=35000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=0
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=1
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=2
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=3
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=4
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=5
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=6
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=7
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=8
# rec days=50 p=0.30 limit=35000 q=0.10 patience=60 seed=9

# %%
rec5 = combineRecorders(recs5)
rec6 = combineRecorders(recs6)
rec7 = combineRecorders(recs7)
rec8 = combineRecorders(recs8)

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Working Time

# %%
rec5.histWorkingTime()
rec6.histWorkingTime()
rec7.histWorkingTime()
rec8.histWorkingTime()
# Fig 3 Hist Daily Working Time 35km

# %%
rec5.plotWorkingTime()
rec6.plotWorkingTime()
rec7.plotWorkingTime()
rec8.plotWorkingTime()
# Plot working time 35km

# %% [markdown]
# #### Tour Length

# %%
rec5.histTourLength()
rec6.histTourLength()
rec7.histTourLength()
rec8.histTourLength()
# Tour Length 35km

# %% [markdown]
# #### Left Over

# %%
rec5.histLeftOver()
rec6.histLeftOver()
rec7.histLeftOver()
rec8.histLeftOver()
# Left over 35km

# %% [markdown]
# #### Parcel Delay

# %%
rec5.tableParcelDelay()
print("\n")
rec6.tableParcelDelay()
print("\n")
rec7.tableParcelDelay()
print("\n")
rec8.tableParcelDelay()
# Out:
# Delivery Delay (9998 parcels)
#    None:   2527   25.3%
#  1 days:   3695   37.0%
#  2 days:   1853   18.5%
#  3 days:    891    8.9%
#  4 days:    477    4.8%
#  5 days:    272    2.7%
#  6 days:    133    1.3%
#  7 days:     91    0.9%
#  8 days:     31    0.3%
#  9 days:     13    0.1%
# 10 days:      8    0.1%
# 11 days:      4    0.0%
# 12 days:      1    0.0%
# 13 days:      1    0.0%
# 14 days:      1    0.0%
#
#
# Delivery Delay (11485 parcels)
#    None:   2755   24.0%
#  1 days:   3695   32.2%
#  2 days:   2594   22.6%
#  3 days:    999    8.7%
#  4 days:    640    5.6%
#  5 days:    330    2.9%
#  6 days:    200    1.7%
#  7 days:    108    0.9%
#  8 days:     83    0.7%
#  9 days:     43    0.4%
# 10 days:     18    0.2%
# 11 days:     11    0.1%
# 12 days:      2    0.0%
# 13 days:      1    0.0%
# 14 days:      4    0.0%
# 15 days:      1    0.0%
# 16 days:      1    0.0%
#
#
# Delivery Delay (13531 parcels)
#    None:   3258   24.1%
#  1 days:   4028   29.8%
#  2 days:   3268   24.2%
#  3 days:   1054    7.8%
#  4 days:    918    6.8%
#  5 days:    443    3.3%
#  6 days:    252    1.9%
#  7 days:    141    1.0%
#  8 days:     74    0.5%
#  9 days:     35    0.3%
# 10 days:     23    0.2%
# 11 days:     13    0.1%
# 12 days:      9    0.1%
# 13 days:      2    0.0%
# 14 days:      5    0.0%
# 15 days:      0    0.0%
# 16 days:      3    0.0%
# 17 days:      1    0.0%
# 18 days:      2    0.0%
# 19 days:      0    0.0%
# 20 days:      2    0.0%
#
#
# Delivery Delay (15010 parcels)
#    None:   3548   23.6%
#  1 days:   3945   26.3%
#  2 days:   3828   25.5%
#  3 days:   1325    8.8%
#  4 days:    946    6.3%
#  5 days:    639    4.3%
#  6 days:    312    2.1%
#  7 days:    187    1.2%
#  8 days:    129    0.9%
#  9 days:     54    0.4%
# 10 days:     44    0.3%
# 11 days:     24    0.2%
# 12 days:     15    0.1%
# 13 days:      5    0.0%
# 14 days:      5    0.0%
# 15 days:      0    0.0%
# 16 days:      1    0.0%
# 17 days:      2    0.0%
# 18 days:      0    0.0%
# 19 days:      0    0.0%
# 20 days:      0    0.0%
# 21 days:      1    0.0%

# %%
rec5.barplotParcelDelay()
rec6.barplotParcelDelay()
rec7.barplotParcelDelay()
rec8.barplotParcelDelay()

# %% [markdown]
# ## Simulation for 40km Bike with 4 different p values (0.2, 0.23, 0.27 and 0.3)

# %%
multiSimulation(range(10), M, W, C, p = 0.2, limit = 40000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.23, limit = 40000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.27, limit = 40000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.3, limit = 40000)
# Out:
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=0
# Simulating the delivery of 985 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=1
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=2
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=3
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=4
# Simulating the delivery of 982 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1020 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1004 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=8
# Simulating the delivery of 976 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1014 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1173 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1120 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1118 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1150 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1094 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1207 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1116 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1192 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1152 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1163 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1346 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1319 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1321 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1379 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1326 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1355 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1338 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1349 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1465 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1492 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1516 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1426 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1573 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1484 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1551 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1507 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................

# %%
recs9 = loadSimulations(range(10), p = 0.2, limit = 40000)
print("\n")
recs10 = loadSimulations(range(10), p = 0.23, limit = 40000)
print("\n")
recs11 = loadSimulations(range(10), p = 0.27, limit = 40000)
print("\n")
recs12 = loadSimulations(range(10), p = 0.3, limit = 40000)
# Out:
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=40000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=0
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=1
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=2
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=3
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=4
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=5
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=6
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=7
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=8
# rec days=50 p=0.23 limit=40000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=0
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=1
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=2
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=3
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=4
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=5
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=6
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=7
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=8
# rec days=50 p=0.27 limit=40000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=0
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=1
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=2
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=3
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=4
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=5
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=6
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=7
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=8
# rec days=50 p=0.30 limit=40000 q=0.10 patience=60 seed=9

# %%
rec9 = combineRecorders(recs9)
rec10 = combineRecorders(recs10)
rec11 = combineRecorders(recs11)
rec12 = combineRecorders(recs12)

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Working Time

# %%
rec9.histWorkingTime()
rec10.histWorkingTime()
rec11.histWorkingTime()
rec12.histWorkingTime()
# Daily Working 40km

# %%
rec9.plotWorkingTime()
rec10.plotWorkingTime()
rec11.plotWorkingTime()
rec12.plotWorkingTime()

# %% [markdown]
# #### Tour Length

# %%
rec9.histTourLength()
rec10.histTourLength()
rec11.histTourLength()
rec12.histTourLength()
# Daily tour length 40km

# %% [markdown]
# #### Left Over

# %%
rec9.histLeftOver()
rec10.histLeftOver()
rec11.histLeftOver()
rec12.histLeftOver()
# Left Over 40km

# %% [markdown]
# #### Parcel Delay

# %%
rec9.tableParcelDelay()
print("\n")
rec10.tableParcelDelay()
print("\n")
rec11.tableParcelDelay()
print("\n")
rec12.tableParcelDelay()
# Out:
# Delivery Delay (9998 parcels)
#    None:   3741   37.4%
#  1 days:   4115   41.2%
#  2 days:   1227   12.3%
#  3 days:    547    5.5%
#  4 days:    211    2.1%
#  5 days:     72    0.7%
#  6 days:     49    0.5%
#  7 days:     15    0.2%
#  8 days:     16    0.2%
#  9 days:      4    0.0%
# 10 days:      1    0.0%
#
#
# Delivery Delay (11485 parcels)
#    None:   3716   32.4%
#  1 days:   4815   41.9%
#  2 days:   1528   13.3%
#  3 days:    817    7.1%
#  4 days:    304    2.6%
#  5 days:    176    1.5%
#  6 days:     64    0.6%
#  7 days:     43    0.4%
#  8 days:     10    0.1%
#  9 days:     12    0.1%
#
#
# Delivery Delay (13531 parcels)
#    None:   4112   30.4%
#  1 days:   5458   40.3%
#  2 days:   1799   13.3%
#  3 days:   1171    8.7%
#  4 days:    462    3.4%
#  5 days:    299    2.2%
#  6 days:    109    0.8%
#  7 days:     49    0.4%
#  8 days:     33    0.2%
#  9 days:     22    0.2%
# 10 days:      8    0.1%
# 11 days:      5    0.0%
# 12 days:      1    0.0%
# 13 days:      3    0.0%
#
#
# Delivery Delay (15010 parcels)
#    None:   4218   28.1%
#  1 days:   5663   37.7%
#  2 days:   2346   15.6%
#  3 days:   1353    9.0%
#  4 days:    676    4.5%
#  5 days:    378    2.5%
#  6 days:    176    1.2%
#  7 days:     88    0.6%
#  8 days:     50    0.3%
#  9 days:     28    0.2%
# 10 days:     16    0.1%
# 11 days:     11    0.1%
# 12 days:      1    0.0%
# 13 days:      4    0.0%
# 14 days:      0    0.0%
# 15 days:      0    0.0%
# 16 days:      0    0.0%
# 17 days:      2    0.0%

# %%
rec9.barplotParcelDelay()
rec10.barplotParcelDelay()
rec11.barplotParcelDelay()
rec12.barplotParcelDelay()

# %% [markdown]
# ## Simulation for 45km Bike with 4 different p values (0.2, 0.23, 0.27 and 0.3)

# %%
multiSimulation(range(10), M, W, C, p = 0.2, limit = 45000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.23, limit = 45000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.27, limit = 45000)
print("\n")
multiSimulation(range(10), M, W, C, p = 0.3, limit = 45000)
# Out:
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=0
# Simulating the delivery of 985 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=1
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=2
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=3
# Simulating the delivery of 993 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=4
# Simulating the delivery of 982 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1020 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1004 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=8
# Simulating the delivery of 976 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1014 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1173 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1120 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1118 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1150 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1094 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1207 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1116 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1192 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1152 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1163 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1346 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1319 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1321 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1379 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1326 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1355 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1399 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1338 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1349 parcels over 50 days to 100 customers
# ..................................................
#
#
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=0
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=1
# Simulating the delivery of 1465 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=2
# Simulating the delivery of 1492 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=3
# Simulating the delivery of 1516 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=4
# Simulating the delivery of 1426 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=5
# Simulating the delivery of 1573 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=6
# Simulating the delivery of 1484 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=7
# Simulating the delivery of 1551 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=8
# Simulating the delivery of 1507 parcels over 50 days to 100 customers
# ..................................................
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=9
# Simulating the delivery of 1498 parcels over 50 days to 100 customers
# ..................................................

# %%
recs13 = loadSimulations(range(10), p = 0.2, limit = 45000)
print("\n")
recs14 = loadSimulations(range(10), p = 0.23, limit = 45000)
print("\n")
recs15 = loadSimulations(range(10), p = 0.27, limit = 45000)
print("\n")
recs16 = loadSimulations(range(10), p = 0.3, limit = 45000)
# Out:
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=0
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=1
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=2
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=3
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=4
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=5
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=6
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=7
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=8
# rec days=50 p=0.20 limit=45000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=0
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=1
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=2
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=3
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=4
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=5
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=6
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=7
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=8
# rec days=50 p=0.23 limit=45000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=0
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=1
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=2
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=3
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=4
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=5
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=6
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=7
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=8
# rec days=50 p=0.27 limit=45000 q=0.10 patience=60 seed=9
#
#
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=0
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=1
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=2
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=3
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=4
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=5
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=6
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=7
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=8
# rec days=50 p=0.30 limit=45000 q=0.10 patience=60 seed=9

# %%
rec13 = combineRecorders(recs13)
rec14 = combineRecorders(recs14)
rec15 = combineRecorders(recs15)
rec16 = combineRecorders(recs16)

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Working Time

# %%
rec13.histWorkingTime()
rec14.histWorkingTime()
rec15.histWorkingTime()
rec16.histWorkingTime()
# DWT 45km

# %%
rec13.plotWorkingTime()
rec14.plotWorkingTime()
rec15.plotWorkingTime()
rec16.plotWorkingTime()

# %% [markdown]
# #### Tour Length

# %%
rec13.histTourLength()
rec14.histTourLength()
rec15.histTourLength()
rec16.histTourLength()
# Fig 4 Historgram Tour lenght

# %% [markdown]
# #### Left Over

# %%
rec13.histLeftOver()
rec14.histLeftOver()
rec15.histLeftOver()
rec16.histLeftOver()

# %% [markdown]
# #### Parcel Delay

# %%
rec13.tableParcelDelay()
print("\n")
rec14.tableParcelDelay()
print("\n")
rec15.tableParcelDelay()
print("\n")
rec16.tableParcelDelay()
# Out:
# Delivery Delay (9998 parcels)
#    None:   5361   53.6%
#  1 days:   3122   31.2%
#  2 days:   1019   10.2%
#  3 days:    346    3.5%
#  4 days:    117    1.2%
#  5 days:     22    0.2%
#  6 days:     10    0.1%
#  7 days:      1    0.0%
#
#
# Delivery Delay (11485 parcels)
#    None:   5167   45.0%
#  1 days:   4245   37.0%
#  2 days:   1309   11.4%
#  3 days:    503    4.4%
#  4 days:    169    1.5%
#  5 days:     68    0.6%
#  6 days:     16    0.1%
#  7 days:      3    0.0%
#  8 days:      5    0.0%
#
#
# Delivery Delay (13531 parcels)
#    None:   5272   39.0%
#  1 days:   5494   40.6%
#  2 days:   1642   12.1%
#  3 days:    689    5.1%
#  4 days:    236    1.7%
#  5 days:    118    0.9%
#  6 days:     50    0.4%
#  7 days:     20    0.1%
#  8 days:      5    0.0%
#  9 days:      1    0.0%
# 10 days:      1    0.0%
# 11 days:      1    0.0%
# 12 days:      2    0.0%
#
#
# Delivery Delay (15010 parcels)
#    None:   5386   35.9%
#  1 days:   6251   41.6%
#  2 days:   1891   12.6%
#  3 days:    868    5.8%
#  4 days:    368    2.5%
#  5 days:    147    1.0%
#  6 days:     50    0.3%
#  7 days:     30    0.2%
#  8 days:      8    0.1%
#  9 days:      4    0.0%
# 10 days:      4    0.0%
# 11 days:      0    0.0%
# 12 days:      2    0.0%
# 13 days:      1    0.0%

# %%
rec13.barplotParcelDelay()
rec14.barplotParcelDelay()
rec15.barplotParcelDelay()
rec16.barplotParcelDelay()
